# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/mandi_prices_raw.csv")

# %%
df.head()
# Out:
#            STATE District Name        Market Name Commodity           Variety  \
# 0    Maharashtra        nashik  Lasalgaon(Niphad)     Wheat  Maharashtra 2189
# 1    Maharashtra        satara              Patan    Tomato             Other
# 2  Uttar Pradesh      mainpuri              Bewar    Potato             Local
# 3      Rajasthan   chittorgarh          Nimbahera     Wheat             Other
# 4      Rajasthan    pratapgarh         Pratapgarh     Onion             Other
#
#   Grade  Min_Price  Max_Price  Modal_Price Price Date
# 0   FAQ     2172.0     2399.0       2300.0   6/6/2023
# 1   FAQ     1000.0     1500.0       1250.0   6/6/2023
# 2   FAQ      800.0      820.0        810.0   6/6/2023
# 3   FAQ     2040.0     2668.0       2300.0   6/6/2023
# 4   FAQ      476.0     1043.0        617.0   6/6/2023

# %%
df.shape
# Out:
# (737392, 10)

# %%
df.columns
# Out:
# Index(['STATE', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min_Price', 'Max_Price', 'Modal_Price', 'Price Date'],
#       dtype='str')

# %%
df.dtypes
# Out:
# STATE                str
# District Name        str
# Market Name          str
# Commodity            str
# Variety              str
# Grade                str
# Min_Price        float64
# Max_Price        float64
# Modal_Price      float64
# Price Date           str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 737392 entries, 0 to 737391
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   STATE          737392 non-null  str
#  1   District Name  737392 non-null  str
#  2   Market Name    737392 non-null  str
#  3   Commodity      737392 non-null  str
#  4   Variety        737392 non-null  str
#  5   Grade          737392 non-null  str
#  6   Min_Price      737392 non-null  float64
#  7   Max_Price      737392 non-null  float64
#  8   Modal_Price    737392 non-null  float64
#  9   Price Date     737392 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 56.3 MB

# %%
df.describe()
# Out:
#            Min_Price      Max_Price    Modal_Price
# count  737392.000000  737392.000000  737392.000000
# mean     2204.849862    2659.733824    2474.484638
# std      1920.977696    2145.250773    2023.851909
# min         0.000000       0.000000       0.000000
# 25%      1100.000000    1500.000000    1300.000000
# 50%      2000.000000    2300.000000    2150.000000
# 75%      2700.000000    3205.000000    3000.000000
# max    420000.000000  480000.000000  460000.000000

# %%
df['Commodity'].unique()
# Out:
# <StringArray>
# ['Wheat', 'Tomato', 'Potato', 'Onion', 'Rice']
# Length: 5, dtype: str

# %%
df[df['Commodity'] == 'Tomato'].head()
# Out:
#                STATE District Name    Market Name Commodity Variety Grade  \
# 1        Maharashtra        satara          Patan    Tomato   Other   FAQ
# 6            Haryana        ambala     Naraingarh    Tomato  Tomato   FAQ
# 9   Himachal Pradesh         mandi  Mandi(Takoli)    Tomato   Other   FAQ
# 10     Uttar Pradesh       sambhal      Muradabad    Tomato   Deshi   FAQ
# 22           Haryana       panipat        Panipat    Tomato   Other   FAQ
#
#     Min_Price  Max_Price  Modal_Price Price Date
# 1      1000.0     1500.0       1250.0   6/6/2023
# 6       500.0      800.0        700.0   6/6/2023
# 9      1100.0     1300.0       1200.0   6/6/2023
# 10      730.0      770.0        750.0   6/6/2023
# 22      400.0      700.0        500.0   6/6/2023

# %%
df.isnull().sum()
# Out:
# STATE            0
# District Name    0
# Market Name      0
# Commodity        0
# Variety          0
# Grade            0
# Min_Price        0
# Max_Price        0
# Modal_Price      0
# Price Date       0
# dtype: int64

# %%
df['STATE'].unique()
# Out:
# <StringArray>
# [      'Maharashtra',     'Uttar Pradesh',         'Rajasthan',
#            'Haryana',       'West Bengal',  'Himachal Pradesh',
#            'Gujarat',         'Meghalaya',    'Madhya Pradesh',
#     'Andhra Pradesh',            'Kerala',          'Nagaland',
#             'Orissa',         'Karnataka',             'Assam',
#             'Punjab',   'Jammu & Kashmir',             'Delhi',
#        'Chattisgarh',             'Bihar',           ' Punjab',
#  'Jammu and Kashmir',      'Chhattisgarh',        'Uttrakhand',
#         'Chandigarh',           'Manipur',         'Tamilnadu',
#            'Tripura',        'Tamil Nadu',               'Gao']
# Length: 30, dtype: str

# %%
tn_df = df[df['STATE'] == 'Tamilnadu']
tn_df.shape
# Out:
# (66602, 10)

# %%
tn_df['Commodity'].unique()
# Out:
# <StringArray>
# ['Onion', 'Potato']
# Length: 2, dtype: str

# %%
tn_df['Price Date'].min(), tn_df['Price Date'].max()
# Out:
# ('1/1/2025', '9/9/2024')

# %%
df['Commodity'].unique()
# Out:
# <StringArray>
# ['Wheat', 'Tomato', 'Potato', 'Onion', 'Rice']
# Length: 5, dtype: str

# %%
df.groupby('STATE')['Commodity'].nunique().sort_values(ascending=False).head(10)
# Out:
# STATE
# Andhra Pradesh      5
# Assam               5
# Gujarat             5
# Himachal Pradesh    5
# Delhi               5
# Karnataka           5
# Rajasthan           5
# Maharashtra         5
# West Bengal         5
# Uttar Pradesh       5
# Name: Commodity, dtype: int64

# %%
df.groupby(['STATE', 'Commodity']).size().unstack()
# Out:
# Commodity            Onion   Potato    Rice  Tomato    Wheat
# STATE
#  Punjab             1186.0   1352.0     NaN   130.0      NaN
# Andhra Pradesh      3879.0   5047.0   106.0   562.0     22.0
# Assam               1468.0   1957.0    96.0   119.0    459.0
# Bihar               5681.0   6597.0     NaN     6.0    170.0
# Chandigarh           427.0    470.0     NaN    52.0      NaN
# Chattisgarh          984.0   1202.0     NaN    59.0    358.0
# Chhattisgarh         938.0   1057.0     NaN    74.0    181.0
# Delhi               1575.0   1562.0    18.0   134.0    424.0
# Gao                    NaN      4.0     NaN     NaN      NaN
# Gujarat             8461.0  10275.0    48.0   805.0   7063.0
# Haryana            26729.0  33640.0     NaN  2846.0      7.0
# Himachal Pradesh    9617.0  11338.0    78.0  1040.0    764.0
# Jammu & Kashmir     2364.0   2743.0     NaN   192.0      NaN
# Jammu and Kashmir    407.0    477.0     NaN    42.0      NaN
# ...

# %%
up_df = df[df['STATE'] == 'Uttar Pradesh']
up_df.shape
# Out:
# (188094, 10)

# %%
up_df['Commodity'].value_counts()
# Out:
# Commodity
# Potato    85744
# Onion     70476
# Wheat     19983
# Tomato     7695
# Rice       4196
# Name: count, dtype: int64

# %%
up_df.isnull().sum()
# Out:
# STATE            0
# District Name    0
# Market Name      0
# Commodity        0
# Variety          0
# Grade            0
# Min_Price        0
# Max_Price        0
# Modal_Price      0
# Price Date       0
# dtype: int64

# %%
up_df['Price Date'].min(), up_df['Price Date'].max()
# Out:
# ('1/1/2024', '9/9/2024')

# %%
up_df.groupby('Commodity')['Price Date'].agg(['min', 'max', 'count'])
# Out:
#                  min       max  count
# Commodity
# Onion       1/1/2024  9/9/2024  70476
# Potato      1/1/2024  9/9/2024  85744
# Rice       4/10/2025  6/6/2025   4196
# Tomato     10/1/2023  9/9/2023   7695
# Wheat       1/1/2024  9/9/2023  19983

# %% [markdown]
# # Day 2 Summary
#
# ## Dataset Chosen
# Indian Agricultural Mandi Prices (2023-2025)
#
# ## Dataset Overview
# - Daily mandi price data
# - Covers Onion, Tomato, Potato, Wheat and Rice
# - Includes all Indian states and union territories
# - Contains market-level price records
#
# ## Key Columns
# - STATE
# - District Name
# - Market Name
# - Commodity
# - Variety
# - Grade
# - Min_Price
# - Max_Price
# - Modal_Price
# - Price Date
#
# ## Initial Findings
# - Price data loaded successfully into Pandas
# - Min_Price, Max_Price and Modal_Price are numeric (float64)
# - Price Date is stored as text and will need conversion to datetime
# - Dataset contains multiple crops and markets
# - Suitable for price prediction and market trend analysis
#
# ## Tasks for Day 3
# - Convert Price Date to datetime format
# - Check for missing values
# - Filter data to selected state(s)
# - Explore crop-wise price distributions
# - Begin data cleaning and preprocessing
